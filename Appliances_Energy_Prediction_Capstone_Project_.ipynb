# %% [markdown]
# <a href="https://colab.research.google.com/github/rajatpal00/Appliances-Energy-Prediction/blob/main/Appliances_Energy_Prediction_Capstone_Project_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data-driven prediction of energy use of appliances**
#
# **The data set is at 10 min for about 4.5 months. The house temperature and humidity conditions were monitored with a ZigBee wireless sensor network. Each wireless node transmitted the temperature and humidity conditions around 3.3 min. Then, the wireless data was averaged for 10 minutes periods. The energy data was logged every 10 minutes with m-bus energy meters. Weather from the nearest airport weather station Chievres Airport, Belgium) was downloaded from a public data set from Reliable Prognosis (rp5.ru) and merged together with the experimental data sets using the date and time column. Two random variables have been included in the data set for testing the regression models and to filter out non-predictive attributes (parameters).**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import warnings
from sklearn.decomposition import PCA, LatentDirichletAllocation
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.neural_network import MLPRegressor
import xgboost as xgb
from sklearn import neighbors
from sklearn.svm import SVR
import time
from math import sqrt
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV

# %%
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.pipeline import Pipeline
from tensorflow.keras import Sequential, layers, Input

# %%
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/MyDrive/AlmaBetter/capstone project/appliance energy prediction/Copy of data_application_energy.csv'
df = pd.read_csv(file_path)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
#  18  RH_8         19735 non-null  float64
#  19  T9           19735 non-null  float64
#  20  RH_9         19735 non-null  float64
#  21  T_out        19735 non-null  float64
#  22  Press_mm_hg  19735 non-null  float64
#  23  RH_out       19735 non-null  float64
#  24  Windspeed    19735 non-null  float64
#  25  Visibility   19735 non-null  float64
#  26  Tdewpoint    19735 non-null  float64
#  27  rv1          19735 non-null  float64
#  28  rv2          19735 non-null  float64
# dtypes: float64(26), int64(2), object(1)
# memory usage: 4.4+ MB

# %% [markdown]
# **Number of entries : 19735 <br> No of features : 27 ( 2 Random Variables included )<br> Target Variable : Appliances <br> All features are numerical. No categorical variables. There seems to be no null values in our data set.**

# %%
df.head()
# Out:
#                   date  Appliances  lights  ...  Tdewpoint        rv1        rv2
# 0  2016-01-11 17:00:00          60      30  ...        5.3  13.275433  13.275433
# 1  2016-01-11 17:10:00          60      30  ...        5.2  18.606195  18.606195
# 2  2016-01-11 17:20:00          50      30  ...        5.1  28.642668  28.642668
# 3  2016-01-11 17:30:00          50      40  ...        5.0  45.410389  45.410389
# 4  2016-01-11 17:40:00          60      40  ...        4.9  10.084097  10.084097
#
# [5 rows x 29 columns]

# %%
df.describe()
# Out:
#          Appliances        lights  ...           rv1           rv2
# count  19735.000000  19735.000000  ...  19735.000000  19735.000000
# mean      97.694958      3.801875  ...     24.988033     24.988033
# std      102.524891      7.935988  ...     14.496634     14.496634
# min       10.000000      0.000000  ...      0.005322      0.005322
# 25%       50.000000      0.000000  ...     12.497889     12.497889
# 50%       60.000000      0.000000  ...     24.897653     24.897653
# 75%      100.000000      0.000000  ...     37.583769     37.583769
# max     1080.000000     70.000000  ...     49.996530     49.996530
#
# [8 rows x 28 columns]

# %%
temp_dict = {
    'T1' : 'temp_kitchen', 'T2' : 'temp_living', 'T3' : 'temp_laundry', 
    'T4' : 'temp_office', 'T5' : 'temp_bath', 'T6' : 'temp_outside',
    'T7' : 'temp_iron', 'T8' : 'temp_teen', 'T9' : 'temp_parents', 'T_out' : 'temp_station'
}

# %%
energy_df = df.rename(columns=temp_dict)

# %%
humid_dict = {
    'RH_1' : 'humid_kitchen', 'RH_2' : 'humid_living', 'RH_3' : 'humid_laundry', 
    'RH_4' : 'humid_office', 'RH_5' : 'humid_bath', 'RH_6' : 'humid_outside',
    'RH_7' : 'humid_iron', 'RH_8' : 'humid_teen', 'RH_9' : 'humid_parents', 'RH_out' : 'humid_station'
}

# %%
energy_df = energy_df.rename(columns=humid_dict)

# %%
energy_df[temp_dict.values()].describe()
# Out:
#        temp_kitchen   temp_living  ...  temp_parents  temp_station
# count  19735.000000  19735.000000  ...  19735.000000  19735.000000
# mean      21.686571     20.341219  ...     19.485828      7.411665
# std        1.606066      2.192974  ...      2.014712      5.317409
# min       16.790000     16.100000  ...     14.890000     -5.000000
# 25%       20.760000     18.790000  ...     18.000000      3.666667
# 50%       21.600000     20.000000  ...     19.390000      6.916667
# 75%       22.600000     21.500000  ...     20.600000     10.408333
# max       26.260000     29.856667  ...     24.500000     26.100000
#
# [8 rows x 10 columns]

# %% [markdown]
# **OBSERVATIONS** : <br>
# 1. **Average outside temperature over a period of 4.5 months is around 7.5 degrees. It ranges from -6 - 28 degrees**
# 2. **While average temperature inside the building has been around 20 degrees for all the rooms. It ranges from 14 - 30 degrees**
# 3. **Which implies, Warming appliances have been used to keep the insides of the building warm. There must be some sort of direct correlation between temperature and consumption of energy inside house.**

# %%
energy_df[humid_dict.values()].describe()
# Out:
#        humid_kitchen  humid_living  ...  humid_parents  humid_station
# count   19735.000000  19735.000000  ...   19735.000000   19735.000000
# mean       40.259739     40.420420  ...      41.552401      79.750418
# std         3.979299      4.069813  ...       4.151497      14.901088
# min        27.023333     20.463333  ...      29.166667      24.000000
# 25%        37.333333     37.900000  ...      38.500000      70.333333
# 50%        39.656667     40.500000  ...      40.900000      83.666667
# 75%        43.066667     43.260000  ...      44.338095      91.666667
# max        63.360000     56.026667  ...      53.326667     100.000000
#
# [8 rows x 10 columns]

# %% [markdown]
# **OBSERVATIONS :**
# 1. **Average humidity outside the building has been higher than the average humidity inside.**
# 2. **Average humidity at the weather station is significantly higher compared to outside humidity near the building.**
# 3. **Average humidity in the bathroom is significantly higher compared to other rooms due to obvious reasons.**
# 4. **Kids and parent room show a comparatively higher average humidity as well signifying the fact that, inhabitants of this building spend most of their time in these buildings.**

# %%
weather_cols = list(set(energy_df.columns) - set(list(temp_dict.values())) - set(list(humid_dict.values())) - {'Appliances', 'lights', 'rv1', 'rv2'})
weather_cols
# Out:
# ['Visibility', 'date', 'Windspeed', 'Press_mm_hg', 'Tdewpoint']

# %% [markdown]
# **Distribution of our appliances energy usage :**

# %%
df.Appliances.describe()
# Out:
# count    19735.000000
# mean        97.694958
# std        102.524891
# min         10.000000
# 25%         50.000000
# 50%         60.000000
# 75%        100.000000
# max       1080.000000
# Name: Appliances, dtype: float64

# %%
sns.histplot(df['Appliances'],bins=50)

# %% [markdown]
# **75% of Appliance consumption is less than 100 Wh . With the maximum consumption of 1080 Wh , there will be outliers in this column and there are small number of cases where consumption is very high**

# %%
df.lights.hist(bins=10)

# %%
df.lights.value_counts()
# Out:
# 0     15252
# 10     2212
# 20     1624
# 30      559
# 40       77
# 50        9
# 60        1
# 70        1
# Name: lights, dtype: int64

# %% [markdown]
# **Since most of the value in lights column is 0, it wont be playing much role in our model. Hence we drop the lights feature from our dataframe.**

# %%
energy_df = energy_df.drop('lights', axis=1)

# %% [markdown]
# ### **Energy consumption**

# %% [markdown]
# **Energy Consumption pattern of the household at different times of the day over different time periods**

# %%
energy_df['weekday'] = ((pd.to_datetime(energy_df['date']).dt.dayofweek)// 5 == 0).astype(int)
energy_df['hour'] = pd.to_datetime(energy_df['date']).dt.hour
energy_df['month'] = pd.to_datetime(energy_df['date']).dt.month

# %%
fig, ax = plt.subplots(1,1,figsize=(7,5))
energy_df.groupby('hour').agg({'Appliances' : 'mean'}).plot.bar(ax=ax)
ax.set_ylabel('Appliance energy (Wh)')
# Out:
# Text(0, 0.5, 'Appliance energy (Wh)')

# %% [markdown]
# **Above figure is a representation of average energy consumption of appliances at different time of the day over a period of 4.5 months. We observe two peak hours. One at 11 am in the morning and other at 6 PM in the evening. While the peak at 11 am is shallow and low, peak at 6 PM is comparatively higher and sharper.**
#
# **We observe that over the sleeping hours (10 PM - 6 AM) the energy consumption of appliances is around 50 Wh. After about 6 AM, energy consumption starts to rise gradually up until 11 AM (probably due to morning chores). And then gradually decreases to around 100 Wh at about 3 PM. After which the energy consumption drastically shoots up up until 6 PM in the evening (probably due to requirement lights in rooms). However energy consumption of appliances reverts back to 50 Wh, as night approaches and people in the house go to bed at around 10 PM.**

# %%
fig, ax = plt.subplots(1,1,figsize=(20,5))
energy_df.groupby(['month','hour']).agg({'Appliances' : 'mean'}).plot.bar(ax=ax)
ax.set_ylabel('Appliance enrergy (Wh)')
# Out:
# Text(0, 0.5, 'Appliance enrergy (Wh)')

# %% [markdown]
# **A trend of high consumption hours for each month seems to be similar to the over all trend**

# %% [markdown]
# **What about weekdays and weekends?**

# %%
fig, ax = plt.subplots(1,2,figsize=(15,5))
week_df = energy_df.groupby(['weekday','hour']).agg({'Appliances':'mean'}).reset_index(0)
week_df[week_df.weekday==0].Appliances.plot.bar(ax=ax[0], label='weekends')
week_df[week_df.weekday==1].Appliances.plot.bar(ax=ax[1], label='weekdays')
ax[0].legend(loc='best')
ax[1].legend(loc='best')
ax[0].set_ylabel('Appliance Energy (Wh)')
ax[1].set_ylabel('Appliance Energy (Wh)')
# Out:
# Text(0, 0.5, 'Appliance Energy (Wh)')

# %% [markdown]
# **We observe that the energy consumption of appliances during the office hours (8 AM - 4 PM) is higher in weekends compared to the weekdays. Also, average overall consumption is higher in weekends is pretty high.**

# %% [markdown]
# **Lets look at how temperature and humidity levels vary inside different rooms !**

# %% [markdown]
# ### **Temperature levels**

# %%
fig, axes = plt.subplots(2,5,figsize=(50,20))
for i, temp in enumerate(temp_dict.values()):
  energy_df.groupby('hour').agg({temp : 'mean'}).plot.bar(ax=axes[i//5, i%5])
  axes[i//5, i%5].legend(loc='best')
  axes[i//5, i%5].set_title(temp)

# %% [markdown]
# **The average temperature inside each of the rooms has been almost constant over the day. However the average temperature outside the building and near the station changes over the course of the day. The average night time temperature is around 6 degree C, while average day time temperature varies over hours and peaks to 12 degree C at about 2-3 PM in the afternoon.**

# %%
fig, ax = plt.subplots(1,1,figsize=(20,5))
energy_df.groupby(['month','hour']).agg({'temp_outside' : 'mean'}).plot.bar(ax=ax)

# %%
fig, axes = plt.subplots(2,5,figsize=(50,20))
for i, temp in enumerate(temp_dict.values()):
  energy_df.groupby('month').agg({temp : 'mean'}).plot.bar(ax=axes[i//5, i%5])
  axes[i//5, i%5].legend(loc='best')
  axes[i//5, i%5].set_title(temp)

# %% [markdown]
# **We observe a significant increasing trend of daytime outside temperatures over the course of 5 months starting from an avg of 4 degree celsius in 1st month to an average of 15 degree celsius in month 5. The outside temperatures seem to have an impact over temperature inside too, although the variance of temperatures inside the building is low, since the temperature inside is controlled. Although the increase temperature seem to have no impact on the appliance consumtion patterns.**

# %% [markdown]
# ### **Humidity levels**

# %%
fig, axes = plt.subplots(2,5,figsize=(50,20))
for i, humid in enumerate(humid_dict.values()):
  energy_df.groupby('hour').agg({humid : 'mean'}).plot.bar(ax=axes[i//5, i%5])
  axes[i//5, i%5].legend(loc='best')
  axes[i//5, i%5].set_title(humid)

# %%
fig, ax = plt.subplots(1,1,figsize=(20,5))
energy_df.groupby(['month','hour']).agg({'humid_outside' : 'mean'}).plot.bar(ax=ax)

# %%
fig, axes = plt.subplots(2,5,figsize=(50,20))
for i, humid in enumerate(humid_dict.values()):
  energy_df.groupby('month').agg({humid : 'mean'}).plot.bar(ax=axes[i//5, i%5])
  axes[i//5, i%5].legend(loc='best')
  axes[i//5, i%5].set_title(humid)

# %% [markdown]
# **Although the humidity outside building tend to decrease over months, the humidity inside rooms seem to be unaffected. The humidity levels outside seem to be negatively correlated to with the temperature levels outside. Lets check !**

# %%
energy_df[['temp_outside', 'humid_outside']].corr()
# Out:
#                temp_outside  humid_outside
# temp_outside       1.000000      -0.672137
# humid_outside     -0.672137       1.000000

# %% [markdown]
# **Indeed there is a strong negative correlation between temperature and humidity levels outside. As temperature increases, moisture levels in the air decreases. We also observe that during the day time when the temperatures are high, humidity levels are low.**

# %% [markdown]
# **Lets look at correlation matrix of temperature and humidity levels**

# %%
cols = list(temp_dict.values())
cols.extend(list(humid_dict.values()))
cols.extend(['Appliances'])
fig, ax = plt.subplots(1,1,figsize=(15,15))
sns.heatmap(energy_df[cols].corr(), ax=ax, annot=True)

# %% [markdown]
# **OBSERVATIONS :**
#
# * **From the correlation graph we clearly observe that the features related to temperature and features related to humidity have positive correlation within themselves whereas have a a very little to no correlation with each other.**
# * **Humidity outside have a strong negative correlation with temperature levels as already discussed.**
# * **Apart from that we observe that a couple features such as humidity at station, temperature outside the building and temperature in the living room have a comparatively high absolute correlation (above 0.12) with Appliances energy consumption.**

# %%
# let us plot the variation of energy consumption with these variables
fig, axes = plt.subplots(4,5,figsize = (50,40))
for i, col in enumerate(cols[:-1]):
  ax = axes[i//5, i%5]
  ax.scatter(energy_df[col], energy_df['Appliances'])
  ax.set_xlabel(col)
  ax.set_ylabel('Appliances')

# %% [markdown]
# **Lets look at the dependence of appliance energy consumption on newly created variables !**

# %%
fig, ax = plt.subplots(1,1,figsize=(7,5))
sns.heatmap(energy_df[['month', 'weekday', 'hour', 'Appliances']].corr(), annot=True, ax=ax)

# %% [markdown]
# * **As we have observed earlier as well, there seenms to be no correlation between month and the observed energy use i.e. the enegy consumption pretty much remains similar over all months. Similarly there is no direct effect of weekdays on appliance energy consumption.**
# * **Although there is a correlation of 0.22 between hour and appliances**

# %%
def create_session(x):
  if x <= 6 or x >= 22:
    return 1
  elif x>6 and x <=15:
    return 2
  else:
    return 3

# %%
# lets create a new column based on our observations
energy_df['session'] = energy_df['hour'].apply(lambda x : create_session(x))

# %%
fig,ax = plt.subplots(1,1,figsize=(7,5))
sns.heatmap(energy_df[['session', 'Appliances']].corr(), ax = ax, annot=True)

# %%
fig, ax = plt.subplots(1,1,figsize=(7,5))
sns.boxplot(x='session',y='Appliances',data=energy_df, ax = ax)

# %% [markdown]
# **We were now able to increase the correlation to 0.34 by making creating this new row. We see a clear distinction of power consumtion in different sessions.**

# %% [markdown]
# **Lets look at features related to weather as well.**

# %%
fig,ax = plt.subplots(1,1,figsize=(20,15))
sns.heatmap(energy_df[weather_cols + cols].corr(), ax = ax, annot=True)

# %% [markdown]
# **Tdewpoint shows a high correlation with most of the tempearture and humidity level features than any other weather parameters. Pressure, windspeed and visibiltiy show little to no correlation. We might need to include these only these features in our final model**

# %% [markdown]
# **Lets now deep dive into reducing the temperature and humidity parameters through some feature engineering and come up with features that explain maximum variability.**

# %%
temp_cols = list(set(list(temp_dict.values())) - {'temp_outside', 'temp_station'})
energy_df['mean_temp'] = energy_df[temp_cols].mean(axis=1)
energy_df[['mean_temp', 'Appliances']].corr()
# Out:
#             mean_temp  Appliances
# mean_temp     1.00000     0.05474
# Appliances    0.05474     1.00000

# %% [markdown]
# **Since most of the temperature variables inside the room show little to know correlation with target variable, lets try to find components that could explain maximum variance, which might improve the correlation with target variable as well.**

# %% [markdown]
# **Before doing PCA, I need to split the data into train and test, and fit PCA on train set**

# %% [markdown]
# ### **PCA on temperatures**

# %%
train_energy_df, test_energy_df = train_test_split(energy_df, test_size=0.2, random_state=1)

# %%
pca = PCA()
pca.fit(train_energy_df[temp_cols])
temp_pca = pca.transform(energy_df[temp_cols])
variance = pca.explained_variance_ratio_*100
fig, ax = plt.subplots(1,1,figsize=(7,5))
ax.bar(range(len(variance)), variance)
ax.plot(range(len(variance)), np.cumsum(variance),'r.-',linewidth=2, label='Cummulative variance %')
ax.set_xlabel('Principal components')
ax.set_ylabel('Explained variance %')
plt.legend(loc='best')

# %%
variance
# Out:
# array([84.42749838,  7.33014216,  2.3562388 ,  2.09550508,  1.47195967,
#         1.21891325,  0.69977714,  0.39996553])

# %% [markdown]
# First two components seem to explain more than 91 % of variance in data.

# %%
for i in range(temp_pca.shape[1]):
  energy_df[f'temp_pca{i+1}'] = temp_pca[:,i]

# %%
fig,ax = plt.subplots(1,1,figsize=(9,7))
sns.heatmap(energy_df[['temp_pca1', 'temp_pca2', 'temp_pca3', 'temp_pca4','temp_pca5', 'temp_pca6', 'temp_pca7', 'temp_pca8', 'Appliances']].corr(), ax = ax, annot=True)

# %%
fig, axes = plt.subplots(1,2,figsize=(13,5))
for i, j in enumerate((6,8)):
  axes[i].scatter(energy_df[f'temp_pca{j}'], energy_df['Appliances'])

# %%
#Lets look at components of humid_pca4
dict(zip(temp_cols, pca.components_[7,:]))
# Out:
# {'temp_bath': -0.217328551591447,
#  'temp_iron': -0.24026540991588433,
#  'temp_kitchen': 0.6252020918393105,
#  'temp_laundry': -0.29689595991058676,
#  'temp_living': -0.1173630470398794,
#  'temp_office': -0.09845473026092923,
#  'temp_parents': 0.6025874320322218,
#  'temp_teen': -0.17157195238503242}

# %% [markdown]
# ### **PCA on humidity**

# %%
humid_cols = list(set(list(humid_dict.values())) - {'humid_outside', 'humid_station'})
energy_df['mean_humid'] = energy_df[temp_cols].mean(axis=1)
energy_df[['mean_humid', 'Appliances']].corr()
# Out:
#             mean_humid  Appliances
# mean_humid     1.00000     0.05474
# Appliances     0.05474     1.00000

# %%
pca = PCA()
pca.fit(train_energy_df[humid_cols])
humid_pca = pca.transform(energy_df[humid_cols])
variance = pca.explained_variance_ratio_*100
fig, ax = plt.subplots(1,1,figsize=(7,5))
ax.bar(range(len(variance)), variance)
ax.plot(range(len(variance)), np.cumsum(variance),'r.-',linewidth=2, label='Cummulative variance %')
ax.set_xlabel('Principal components')
ax.set_ylabel('Explained variance %')
plt.legend(loc='best')

# %%
variance
# Out:
# array([62.09137315, 28.02035975,  3.84761759,  2.19313449,  1.40502588,
#         1.22143306,  0.64956943,  0.57148664])

# %%
for i in range(humid_pca.shape[1]):
  energy_df[f'humid_pca{i+1}'] = humid_pca[:,i]

# %%
fig,ax = plt.subplots(1,1,figsize=(7,5))
sns.heatmap(energy_df[['humid_pca1', 'humid_pca2', 'humid_pca3', 'humid_pca4', 'humid_pca6', 'humid_pca7', 'humid_pca8', 'Appliances']].corr(), ax = ax, annot=True)

# %%
plt.scatter(energy_df['humid_pca4'], energy_df['Appliances'])

# %%
#Lets look at components of humid_pca4
dict(zip(humid_cols, pca.components_[3,:]))
# Out:
# {'humid_bath': -0.005052352457213735,
#  'humid_iron': 0.07897694512980066,
#  'humid_kitchen': 0.4123122284268883,
#  'humid_laundry': 0.29088037088151,
#  'humid_living': -0.5395785231761465,
#  'humid_office': 0.4102126219725884,
#  'humid_parents': -0.018904279237054095,
#  'humid_teen': -0.5285334448509871}

# %%
energy_df['diff_temp'] = energy_df['temp_outside'] - energy_df['mean_temp']
energy_df[['diff_temp', 'Appliances']].corr()
# Out:
#             diff_temp  Appliances
# diff_temp     1.00000     0.12411
# Appliances    0.12411     1.00000

# %%
energy_df['log_Appliances'] = np.log(energy_df['Appliances'])
sns.histplot(energy_df.log_Appliances,bins=50)

# %% [markdown]
# # **Modeling with PCA features**

# %%
final_features = ['temp_pca1', 'temp_pca2', 'humid_pca1', 'humid_pca2', 'temp_outside', 'humid_outside', 'weekday', 'session', 'Windspeed', 'Press_mm_hg', 'Appliances']

# %%
fig,ax = plt.subplots(1,1,figsize=(7,5))
sns.heatmap(energy_df[final_features].corr(), ax = ax, annot=True)

# %%
final_train_df, final_test_df = train_test_split(energy_df[final_features], test_size = 0.2, random_state = 1)

# %%
X_train, y_train = final_train_df.drop('Appliances', axis=1), final_train_df['Appliances']
X_test, y_test = final_test_df.drop('Appliances', axis=1), final_test_df['Appliances']

# %%
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

# %%
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train.values.reshape([-1,1])).flatten()
y_test = sc_y.transform(y_test.values.reshape([-1,1])).flatten()

# %% [markdown]
# **The ML regressor models that we use are :**
# * **Lasso Regressor**
# * **Ridge Regressor**
# * **KNeighbors Regressor**
# * **Support Vector Regressor**
# * **Random Forest Regressor**
# * **Extra Tree Regressor**
# * **Gradient Boosting Regressor**
# * **XGB Regressor**
# * **MLP Regressor**

# %%
models = [
           ['Lasso: ', Lasso()],
           ['Ridge: ', Ridge()],
           ['KNeighborsRegressor: ',  neighbors.KNeighborsRegressor()],
           ['SVR:' , SVR(kernel='rbf')],
           ['RandomForest ',RandomForestRegressor()],
           ['ExtraTreeRegressor :',ExtraTreesRegressor()],
           ['GradientBoostingRegressor: ', GradientBoostingRegressor()] ,
           ['XGBRegressor: ', xgb.XGBRegressor()] ,
           ['MLPRegressor: ', MLPRegressor(  activation='relu', solver='adam',learning_rate='adaptive',max_iter=1000,learning_rate_init=0.01,alpha=0.01)]
         ]

# %%
model_data = []
for name,curr_model in models :
    curr_model_data = {}
    curr_model.random_state = 78
    curr_model_data["Name"] = name
    start = time.time()
    curr_model.fit(X_train,y_train)
    end = time.time()
    curr_model_data["Train_Time"] = end - start
    curr_model_data["Train_R2_Score"] = r2_score(y_train,curr_model.predict(X_train))
    curr_model_data["Test_R2_Score"] = r2_score(y_test,curr_model.predict(X_test))
    curr_model_data["Test_RMSE_Score"] = np.sqrt(mean_squared_error(y_test,curr_model.predict(X_test)))
    model_data.append(curr_model_data)
# Out:
# [07:13:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
results_df = df = pd.DataFrame(model_data)

# %%
results_df
# Out:
#                           Name  Train_Time  ...  Test_R2_Score  Test_RMSE_Score
# 0                      Lasso:     0.009166  ...      -0.000777         1.028791
# 1                      Ridge:     0.009007  ...       0.124513         0.962240
# 2        KNeighborsRegressor:     0.044262  ...       0.473707         0.746057
# 3                         SVR:   14.046903  ...       0.142784         0.952146
# 4                RandomForest    13.585982  ...       0.559070         0.682878
# 5         ExtraTreeRegressor :    3.887098  ...       0.644547         0.613125
# 6  GradientBoostingRegressor:     3.959479  ...       0.217850         0.909501
# 7               XGBRegressor:     1.140274  ...       0.213623         0.911956
# 8               MLPRegressor:     6.240486  ...       0.260662         0.884260
#
# [9 rows x 5 columns]

# %%
results_df.plot.bar(x="Name", y=['Test_R2_Score' , 'Train_R2_Score' , 'Test_RMSE_Score'], title = 'Results' , width = .6, figsize= (20,8))

# %% [markdown]
# **OBSERVATIONS :**
#
# * **Extra Tree Regressor performs the best so far with a R2 score of 0.59 and RMSE of 0.65.**
# * **Lasso regression is the worst performing model so far.**

# %% [markdown]
# # **Hyper-parameter Tuning**

# %%
from sklearn.model_selection import GridSearchCV
param_grid = [{
              'max_depth': [80, 150, 200,250],
              'n_estimators' : [100,150,200,250],
              'max_features': ["auto", "sqrt", "log2"]
            }]
reg = ExtraTreesRegressor(random_state=40)
grid_search = GridSearchCV(estimator = reg, param_grid = param_grid, cv = 5, n_jobs = -1 , scoring='r2' , verbose=2)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 158 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=-1)]: Done 240 out of 240 | elapsed: 11.4min finished
# GridSearchCV(cv=5, error_score=nan,
#              estimator=ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0,
#                                            criterion='mse', max_depth=None,
#                                            max_features='auto',
#                                            max_leaf_nodes=None,
#                                            max_samples=None,
#                                            min_impurity_decrease=0.0,
#                                            min_impurity_split=None,
#                                            min_samples_leaf=1,
#                                            min_samples_split=2,
#                                            min_weight_fraction_leaf=0.0,
#                                            n_estimators=100, n_jobs=None,
#                                            oob_score=False, random_state=40,
#                                            verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid=[{'max_depth': [80, 150, 200, 250],
#                           'max_features': ['auto', 'sqrt', 'log2'],
#                           'n_estimators': [100, 150, 200, 250]}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='r2', verbose=2)

# %%
grid_search.best_params_
# Out:
# {'max_depth': 80, 'max_features': 'sqrt', 'n_estimators': 250}

# %%
grid_search.best_estimator_
# Out:
# ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=80, max_features='sqrt', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=2, min_weight_fraction_leaf=0.0,
#                     n_estimators=250, n_jobs=None, oob_score=False,
#                     random_state=40, verbose=0, warm_start=False)

# %%
grid_search.best_estimator_.score(X_train,y_train)
# Out:
# 1.0

# %%
grid_search.best_estimator_.score(X_test,y_test)
# Out:
# 0.6451811161505343

# %%
np.sqrt(mean_squared_error(y_test, grid_search.best_estimator_.predict(X_test)))
# Out:
# 0.6125783423942577

# %% [markdown]
# **We observe a minute improvement in R2 score and RMSE score after hyper parameter tuning of Extra Trees Regressor.**

# %%
errors = []
errors.append(np.sqrt(mean_squared_error(y_test[y_test*sc_y.scale_ + sc_y.mean_ < 300]*sc_y.scale_ + sc_y.mean_, grid_search.best_estimator_.predict(X_test[y_test*sc_y.scale_ + sc_y.mean_ < 300,:])*sc_y.scale_ + sc_y.mean_)))

# %%
errors.append(np.sqrt(mean_squared_error(y_test[y_test*sc_y.scale_ + sc_y.mean_ > 300]*sc_y.scale_ + sc_y.mean_, grid_search.best_estimator_.predict(X_test[y_test*sc_y.scale_ + sc_y.mean_ > 300,:])*sc_y.scale_ + sc_y.mean_)))

# %%
plt.bar(x=['Below 300', 'Above 300'], height=errors, width = 0.5)
plt.axhline(np.sqrt(mean_squared_error(y_test*sc_y.scale_ + sc_y.mean_, grid_search.best_estimator_.predict(X_test)*sc_y.scale_ + sc_y.mean_)), color='red', label='average RMSE')
plt.xlabel('Appliances Energy (Wh)')
plt.ylabel('RMSE')
plt.legend(loc='best')

# %% [markdown]
# **The model seems to make more errors in predicting the ones where actual energy consumption levels of appliances is quite high (above 300 Wh). While below 300 Wh, the RMSE is below the average RMS of entire test set.**

# %%
X_test = pd.DataFrame(X_test, columns=final_features[:-1])
y_test = pd.Series(y_test, name = 'Appliances')

# %%
session_errors = []
for i in range(1,4):
  session_errors.append(np.sqrt(mean_squared_error(y_test[X_test.session*sc_X.scale_[-3] + sc_X.mean_[-3] == i]*sc_y.scale_ + sc_y.mean_, grid_search.best_estimator_.predict(X_test[X_test.session*sc_X.scale_[-3] + sc_X.mean_[-3] == i])*sc_y.scale_ + sc_y.mean_)))

# %%
plt.bar(x=['10 PM - 6 AM', '6 AM - 3 PM', '3 PM - 10 PM'], height=session_errors, width = 0.5)
plt.axhline(np.sqrt(mean_squared_error(y_test*sc_y.scale_ + sc_y.mean_, grid_search.best_estimator_.predict(X_test)*sc_y.scale_ + sc_y.mean_)), color='red', label='average RMSE')
plt.xlabel('Appliances Energy (Wh)')
plt.ylabel('RMSE')
plt.legend(loc='best')

# %% [markdown]
# **When we look at the root mean squared errors made in prediction of energy consumption in appliances at different time of the day, we observe that errors made are quite less than the average RMSE of entire test set. Which is quite intuitive since we had little to no variance in energy consumption in those hours. However the errors are above average for other two time frames, where we had seen a quite a variance in energy levels.**

# %%
fig, axes = plt.subplots(1,1,figsize=(20,5))
plt.plot(range(len(y_test[:200])), y_test[:200]*sc_y.scale_ + sc_y.mean_, label='actual')
plt.plot(range(len(y_test[:200])), grid_search.best_estimator_.predict(X_test.iloc[:200,:])*sc_y.scale_ + sc_y.mean_, label='predicted')
plt.legend(loc='best')
plt.ylabel('Appliance energy consumption (Wh)')
plt.xlabel('Samples')
# Out:
# Text(0.5, 0, 'Samples')

# %%
feature_indices = np.argsort(grid_search.best_estimator_.feature_importances_)
importances = grid_search.best_estimator_.feature_importances_
indices = np.argsort(importances)[::-1]
names = [final_train_df.columns[i] for i in indices]

plt.figure(figsize=(10,6))
plt.title("Feature Importance")
plt.bar(range(X_train.shape[1]), importances[indices])
plt.xticks(range(X_train.shape[1]), names, rotation=90)
plt.show()

# %% [markdown]
# **Looking at the feature importances, it is clear that the PCA features of temperature and humidity hold slightly higher feature importances compared to others. However almost all the features used for modelling hold equal importance**

# %% [markdown]
# # **Modeling Without PCA features**

# %% [markdown]
# **Including all temperature and humidity features and engineered feature 'session' in our features set.**

# %%
final_features = ['temp_laundry','temp_bath', 'temp_kitchen', 'temp_parents', 'temp_office', 'temp_living', 'temp_teen', 'temp_iron','humid_kitchen',
 'humid_office', 'humid_bath', 'humid_living', 'humid_parents', 'humid_laundry', 'humid_teen', 'humid_iron',
  'temp_outside', 'humid_outside', 'temp_station', 'humid_station', 'weekday', 'session', 'Windspeed', 'Press_mm_hg', 'Appliances']

# %%
final_train_df, final_test_df = train_test_split(energy_df[final_features], test_size = 0.2, random_state = 1)

# %%
X_train, y_train = final_train_df.drop('Appliances', axis=1), final_train_df['Appliances']
X_test, y_test = final_test_df.drop('Appliances', axis=1), final_test_df['Appliances']

# %%
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

# %%
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train.values.reshape([-1,1])).flatten()
y_test = sc_y.transform(y_test.values.reshape([-1,1])).flatten()

# %%
models = [
           ['Lasso: ', Lasso()],
           ['Ridge: ', Ridge()],
           ['KNeighborsRegressor: ',  neighbors.KNeighborsRegressor()],
           ['SVR:' , SVR(kernel='rbf')],
           ['RandomForest ',RandomForestRegressor()],
           ['ExtraTreeRegressor :',ExtraTreesRegressor()],
           ['GradientBoostingRegressor: ', GradientBoostingRegressor()],
           ['XGBRegressor: ', xgb.XGBRegressor()],
           ['MLPRegressor: ', MLPRegressor(  activation='relu', solver='adam',learning_rate='adaptive',max_iter=1000,learning_rate_init=0.01,alpha=0.01)]
         ]

# %%
model_data = []
for name,curr_model in models :
    curr_model_data = {}
    curr_model.random_state = 78
    curr_model_data["Name"] = name
    start = time.time()
    curr_model.fit(X_train,y_train)
    end = time.time()
    curr_model_data["Train_Time"] = end - start
    curr_model_data["Train_R2_Score"] = r2_score(y_train,curr_model.predict(X_train))
    curr_model_data["Test_R2_Score"] = r2_score(y_test,curr_model.predict(X_test))
    curr_model_data["Test_RMSE_Score"] = np.sqrt(mean_squared_error(y_test,curr_model.predict(X_test)))
    model_data.append(curr_model_data)
# Out:
# [07:31:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
results_df = pd.DataFrame(model_data)

# %%
results_df
# Out:
#                           Name  Train_Time  ...  Test_R2_Score  Test_RMSE_Score
# 0                      Lasso:     0.011277  ...      -0.000777         1.028791
# 1                      Ridge:     0.009561  ...       0.185596         0.928064
# 2        KNeighborsRegressor:     0.122831  ...       0.485173         0.737886
# 3                         SVR:   16.475175  ...       0.242499         0.895055
# 4                RandomForest    32.341253  ...       0.593254         0.655873
# 5         ExtraTreeRegressor :    8.225008  ...       0.645417         0.612374
# 6  GradientBoostingRegressor:     7.425947  ...       0.271252         0.877904
# 7               XGBRegressor:     1.571919  ...       0.271605         0.877691
# 8               MLPRegressor:     9.661272  ...       0.397394         0.798316
#
# [9 rows x 5 columns]

# %%
results_df.plot.bar(x="Name", y=['Test_R2_Score' , 'Train_R2_Score' , 'Test_RMSE_Score'], title = 'Results' , width = .6, figsize= (20,8))

# %% [markdown]
# **The model results are almost similar to that observed in models trained with PCA feature set.**

# %% [markdown]
# # **Hyper-parameter Tuning**

# %%
param_grid = [{
              'max_depth': [80, 150, 200,250],
              'n_estimators' : [100,150,200,250],
              'max_features': ["auto", "sqrt", "log2"]
            }]
reg = ExtraTreesRegressor(random_state=40)
grid_search = GridSearchCV(estimator = reg, param_grid = param_grid, cv = 5, n_jobs = -1 , scoring='r2' , verbose=2)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 158 tasks      | elapsed: 13.2min
# [Parallel(n_jobs=-1)]: Done 240 out of 240 | elapsed: 19.0min finished
# GridSearchCV(cv=5, error_score=nan,
#              estimator=ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0,
#                                            criterion='mse', max_depth=None,
#                                            max_features='auto',
#                                            max_leaf_nodes=None,
#                                            max_samples=None,
#                                            min_impurity_decrease=0.0,
#                                            min_impurity_split=None,
#                                            min_samples_leaf=1,
#                                            min_samples_split=2,
#                                            min_weight_fraction_leaf=0.0,
#                                            n_estimators=100, n_jobs=None,
#                                            oob_score=False, random_state=40,
#                                            verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid=[{'max_depth': [80, 150, 200, 250],
#                           'max_features': ['auto', 'sqrt', 'log2'],
#                           'n_estimators': [100, 150, 200, 250]}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='r2', verbose=2)

# %%
grid_search.best_params_
# Out:
# {'max_depth': 80, 'max_features': 'sqrt', 'n_estimators': 150}

# %%
grid_search.best_estimator_
# Out:
# ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=80, max_features='sqrt', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=2, min_weight_fraction_leaf=0.0,
#                     n_estimators=150, n_jobs=None, oob_score=False,
#                     random_state=40, verbose=0, warm_start=False)

# %%
grid_search.best_estimator_.score(X_train,y_train)
# Out:
# 1.0

# %%
grid_search.best_estimator_.score(X_test,y_test)
# Out:
# 0.6492753651955736

# %%
np.sqrt(mean_squared_error(y_test, grid_search.best_estimator_.predict(X_test)))
# Out:
# 0.6090338221675987

# %%
errors = []
errors.append(np.sqrt(mean_squared_error(y_test[y_test*sc_y.scale_ + sc_y.mean_ < 300]*sc_y.scale_ + sc_y.mean_, grid_search.best_estimator_.predict(X_test[y_test*sc_y.scale_ + sc_y.mean_ < 300,:])*sc_y.scale_ + sc_y.mean_)))

# %%
errors.append(np.sqrt(mean_squared_error(y_test[y_test*sc_y.scale_ + sc_y.mean_ > 300]*sc_y.scale_ + sc_y.mean_, grid_search.best_estimator_.predict(X_test[y_test*sc_y.scale_ + sc_y.mean_ > 300,:])*sc_y.scale_ + sc_y.mean_)))

# %%
plt.bar(x=['Below 300', 'Above 300'], height=errors, width = 0.5)
plt.axhline(np.sqrt(mean_squared_error(y_test*sc_y.scale_ + sc_y.mean_, grid_search.best_estimator_.predict(X_test)*sc_y.scale_ + sc_y.mean_)), color='red', label='average RMSE')
plt.xlabel('Appliances Energy (Wh)')
plt.ylabel('RMSE')
plt.legend(loc='best')

# %% [markdown]
# **The model seems to make more errors in predicting the ones where actual energy consumption levels of appliances is quite high (above 300 Wh). While below 300 Wh, the RMSE is below the average RMS of entire test set.**

# %%
X_test = pd.DataFrame(X_test, columns=final_features[:-1])
y_test = pd.Series(y_test, name = 'Appliances')

# %%
session_errors = []
for i in range(1,4):
  session_errors.append(np.sqrt(mean_squared_error(y_test[X_test.session*sc_X.scale_[-3] + sc_X.mean_[-3] == i]*sc_y.scale_ + sc_y.mean_, grid_search.best_estimator_.predict(X_test[X_test.session*sc_X.scale_[-3] + sc_X.mean_[-3] == i])*sc_y.scale_ + sc_y.mean_)))

# %%
plt.bar(x=['10 PM - 6 AM', '6 AM - 3 PM', '3 PM - 10 PM'], height=session_errors, width = 0.5)
plt.axhline(np.sqrt(mean_squared_error(y_test*sc_y.scale_ + sc_y.mean_, grid_search.best_estimator_.predict(X_test)*sc_y.scale_ + sc_y.mean_)), color='red', label='average RMSE')
plt.xlabel('Session (Time of the day)')
plt.ylabel('RMSE')
plt.legend(loc='best')

# %% [markdown]
# **When we look at the root mean squared errors made in prediction of energy consumption in appliances at different time of the day, we observe that errors made are quite less than the average RMSE of entire test set. Which is quite intuitive since we had little to no variance in energy consumption in those hours. However the errors are above average for other two time frames, where we had seen a quite a variance in energy levels.**

# %%
fig, axes = plt.subplots(1,1,figsize=(20,5))
plt.plot(range(len(y_test[:200])), y_test[:200]*sc_y.scale_ + sc_y.mean_, label='actual',linewidth=2)
plt.plot(range(len(y_test[:200])), grid_search.best_estimator_.predict(X_test.iloc[:200,:])*sc_y.scale_ + sc_y.mean_, label='predicted',linewidth=2)
plt.legend(loc='best')
plt.ylabel('Appliance energy consumption (Wh)')
plt.xlabel('Samples')
# Out:
# Text(0.5, 0, 'Samples')

# %% [markdown]
# **The above figure represents actual and predicted values of 200 samples in test set.**

# %%
feature_indices = np.argsort(grid_search.best_estimator_.feature_importances_)
importances = grid_search.best_estimator_.feature_importances_
indices = np.argsort(importances)[::-1]
names = [final_train_df.columns[i] for i in indices]

plt.figure(figsize=(10,6))
plt.title("Feature Importance")
plt.bar(range(X_train.shape[1]), importances[indices])
plt.xticks(range(X_train.shape[1]), names, rotation=90)
plt.show()

# %% [markdown]
# **In the case where we don't include any PCA features, the engineered feature 'session' seems to hold most importance among all the features.**

# %% [markdown]
# # **Neural Networks**

# %%
final_features = ['temp_pca1', 'temp_pca2', 'humid_pca1', 'humid_pca2', 'temp_outside', 'humid_outside', 'session', 'Windspeed', 'Press_mm_hg', 'weekday', 'Appliances']

# %%
final_train_df, final_test_df = train_test_split(energy_df[final_features], test_size = 0.2, random_state = 1)

# %%
X_train, y_train = final_train_df.drop('Appliances', axis=1), final_train_df['Appliances']
X_test, y_test = final_test_df.drop('Appliances', axis=1), final_test_df['Appliances']

# %%
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

# %%
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train.values.reshape([-1,1])).flatten()
y_test = sc_y.transform(y_test.values.reshape([-1,1])).flatten()

# %%
def R_squared(y_true, y_pred):
  unexplained_error = tf.reduce_sum(tf.square(y_true - y_pred))
  total_error = tf.reduce_sum(tf.square(y_true - tf.reduce_mean(y_true, axis=0)))
  R2 = 1. - tf.truediv(unexplained_error, total_error)
  return R2

# %%
NN_model = Sequential([
                    Input((None,X_train.shape[1])),
                    layers.Dense(32,activation='relu',kernel_initializer='normal'),
                    layers.Dense(64,activation='relu', kernel_initializer='normal'),
                    layers.Dense(64,activation='relu', kernel_initializer='normal'),
                    layers.Dense(1,kernel_initializer='normal',activation='linear'),
])
NN_model.compile(loss='mean_squared_error', optimizer='adam', metrics=[R_squared])
NN_model.summary()
# Out:
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, None, 32)          352
# _________________________________________________________________
# dense_1 (Dense)              (None, None, 64)          2112
# _________________________________________________________________
# dense_2 (Dense)              (None, None, 64)          4160
# _________________________________________________________________
# dense_3 (Dense)              (None, None, 1)           65
# =================================================================
# Total params: 6,689
# Trainable params: 6,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf

# %%
NN_model.fit(X_train, y_train, epochs=500, validation_data=(X_test, y_test), workers=-1)
# Out:
# Epoch 1/500
# WARNING:tensorflow:Model was constructed with shape (None, None, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 10), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'"), but it was called on an input with incompatible shape (None, 10).
# WARNING:tensorflow:Model was constructed with shape (None, None, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 10), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'"), but it was called on an input with incompatible shape (None, 10).
# 484/494 [============================>.] - ETA: 0s - loss: 0.8835 - R_squared: 0.0383WARNING:tensorflow:Model was constructed with shape (None, None, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 10), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'"), but it was called on an input with incompatible shape (None, 10).
# 494/494 [==============================] - 2s 2ms/step - loss: 0.8806 - R_squared: 0.0403 - val_loss: 0.8976 - val_R_squared: 0.1194
# Epoch 2/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.8353 - R_squared: 0.0704 - val_loss: 0.8824 - val_R_squared: 0.1225
# Epoch 3/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.8077 - R_squared: 0.0902 - val_loss: 0.8618 - val_R_squared: 0.1352
# Epoch 4/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.7817 - R_squared: 0.1111 - val_loss: 0.8373 - val_R_squared: 0.1662
# Epoch 5/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.7622 - R_squared: 0.1351 - val_loss: 0.8232 - val_R_squared: 0.1802
# Epoch 6/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.7499 - R_squared: 0.0910 - val_loss: 0.8050 - val_R_squared: 0.1939
# Epoch 7/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.7260 - R_squared: 0.1641 - val_loss: 0.7968 - val_R_squared: 0.1719
# Epoch 8/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.7143 - R_squared: 0.2094 - val_loss: 0.7732 - val_R_squared: 0.2094
# Epoch 9/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.6989 - R_squared: 0.1881 - val_loss: 0.7904 - val_R_squared: 0.2299
# Epoch 10/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.6927 - R_squared: 0.1926 - val_loss: 0.7563 - val_R_squared: 0.2227
# Epoch 11/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.6769 - R_squared: 0.2022 - val_loss: 0.7490 - val_R_squared: 0.2290
# Epoch 12/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.6729 - R_squared: 0.1969 - val_loss: 0.7318 - val_R_squared: 0.2305
# Epoch 13/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.6657 - R_squared: 0.1931 - val_loss: 0.7488 - val_R_squared: 0.1494
# Epoch 14/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.6618 - R_squared: 0.2262 - val_loss: 0.7282 - val_R_squared: 0.2610
# Epoch 15/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.6537 - R_squared: 0.2012 - val_loss: 0.7581 - val_R_squared: 0.1352
# Epoch 16/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.6516 - R_squared: 0.2274 - val_loss: 0.7420 - val_R_squared: 0.2432
# Epoch 17/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.6466 - R_squared: 0.2333 - val_loss: 0.7180 - val_R_squared: 0.2080
# Epoch 18/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.6402 - R_squared: 0.2428 - val_loss: 0.7390 - val_R_squared: 0.1739
# Epoch 19/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.6334 - R_squared: 0.2472 - val_loss: 0.6999 - val_R_squared: 0.2615
# Epoch 20/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.6296 - R_squared: 0.2180 - val_loss: 0.7198 - val_R_squared: 0.2205
# Epoch 21/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.6203 - R_squared: 0.2553 - val_loss: 0.7181 - val_R_squared: 0.2098
# Epoch 22/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.6169 - R_squared: 0.2600 - val_loss: 0.7103 - val_R_squared: 0.2604
# Epoch 23/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.6156 - R_squared: 0.2380 - val_loss: 0.6994 - val_R_squared: 0.2666
# Epoch 24/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.6079 - R_squared: 0.2576 - val_loss: 0.6895 - val_R_squared: 0.2768
# Epoch 25/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.6086 - R_squared: 0.3029 - val_loss: 0.6956 - val_R_squared: 0.2711
# Epoch 26/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.6025 - R_squared: 0.2777 - val_loss: 0.7099 - val_R_squared: 0.1682
# Epoch 27/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5930 - R_squared: 0.2998 - val_loss: 0.6807 - val_R_squared: 0.2660
# Epoch 28/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5926 - R_squared: 0.2395 - val_loss: 0.6830 - val_R_squared: 0.2468
# Epoch 29/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5847 - R_squared: 0.2656 - val_loss: 0.7419 - val_R_squared: 0.1010
# Epoch 30/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5886 - R_squared: 0.2990 - val_loss: 0.6830 - val_R_squared: 0.2393
# Epoch 31/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5777 - R_squared: 0.3195 - val_loss: 0.6976 - val_R_squared: 0.2153
# Epoch 32/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5705 - R_squared: 0.2949 - val_loss: 0.7154 - val_R_squared: 0.1533
# Epoch 33/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5777 - R_squared: 0.2822 - val_loss: 0.6913 - val_R_squared: 0.1882
# Epoch 34/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5721 - R_squared: 0.3139 - val_loss: 0.6706 - val_R_squared: 0.2551
# Epoch 35/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5699 - R_squared: 0.2873 - val_loss: 0.6971 - val_R_squared: 0.2188
# Epoch 36/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5667 - R_squared: 0.2998 - val_loss: 0.6518 - val_R_squared: 0.2860
# Epoch 37/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5620 - R_squared: 0.3066 - val_loss: 0.6687 - val_R_squared: 0.2521
# Epoch 38/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5557 - R_squared: 0.3288 - val_loss: 0.6669 - val_R_squared: 0.2610
# Epoch 39/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5503 - R_squared: 0.3082 - val_loss: 0.6614 - val_R_squared: 0.3004
# Epoch 40/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5505 - R_squared: 0.3277 - val_loss: 0.6590 - val_R_squared: 0.2610
# Epoch 41/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5477 - R_squared: 0.3122 - val_loss: 0.7034 - val_R_squared: 0.1936
# Epoch 42/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5428 - R_squared: 0.3536 - val_loss: 0.6691 - val_R_squared: 0.3040
# Epoch 43/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5335 - R_squared: 0.3387 - val_loss: 0.6510 - val_R_squared: 0.2639
# Epoch 44/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5372 - R_squared: 0.3344 - val_loss: 0.6674 - val_R_squared: 0.2423
# Epoch 45/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5326 - R_squared: 0.3057 - val_loss: 0.6583 - val_R_squared: 0.2811
# Epoch 46/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5302 - R_squared: 0.3516 - val_loss: 0.6457 - val_R_squared: 0.3118
# Epoch 47/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5296 - R_squared: 0.3504 - val_loss: 0.6870 - val_R_squared: 0.1951
# Epoch 48/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5249 - R_squared: 0.3339 - val_loss: 0.6479 - val_R_squared: 0.2872
# Epoch 49/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5264 - R_squared: 0.3230 - val_loss: 0.6363 - val_R_squared: 0.2912
# Epoch 50/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5134 - R_squared: 0.3334 - val_loss: 0.6497 - val_R_squared: 0.3145
# Epoch 51/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5240 - R_squared: 0.3024 - val_loss: 0.6614 - val_R_squared: 0.2578
# Epoch 52/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5167 - R_squared: 0.3424 - val_loss: 0.6627 - val_R_squared: 0.2930
# Epoch 53/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5123 - R_squared: 0.3360 - val_loss: 0.6614 - val_R_squared: 0.2311
# Epoch 54/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5108 - R_squared: 0.3684 - val_loss: 0.6592 - val_R_squared: 0.2659
# Epoch 55/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5094 - R_squared: 0.3664 - val_loss: 0.6682 - val_R_squared: 0.3054
# Epoch 56/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5059 - R_squared: 0.3998 - val_loss: 0.6429 - val_R_squared: 0.2654
# Epoch 57/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5010 - R_squared: 0.3602 - val_loss: 0.6349 - val_R_squared: 0.3101
# Epoch 58/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4953 - R_squared: 0.3712 - val_loss: 0.6420 - val_R_squared: 0.2619
# Epoch 59/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4940 - R_squared: 0.3624 - val_loss: 0.6431 - val_R_squared: 0.3121
# Epoch 60/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4934 - R_squared: 0.3984 - val_loss: 0.6442 - val_R_squared: 0.2460
# Epoch 61/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4895 - R_squared: 0.3936 - val_loss: 0.6175 - val_R_squared: 0.3282
# Epoch 62/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4900 - R_squared: 0.3927 - val_loss: 0.6579 - val_R_squared: 0.2242
# Epoch 63/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4797 - R_squared: 0.3912 - val_loss: 0.6499 - val_R_squared: 0.2108
# Epoch 64/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4853 - R_squared: 0.4224 - val_loss: 0.6375 - val_R_squared: 0.2584
# Epoch 65/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4825 - R_squared: 0.4152 - val_loss: 0.6374 - val_R_squared: 0.3107
# Epoch 66/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4807 - R_squared: 0.4236 - val_loss: 0.6065 - val_R_squared: 0.3330
# Epoch 67/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4765 - R_squared: 0.3800 - val_loss: 0.6331 - val_R_squared: 0.3060
# Epoch 68/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4797 - R_squared: 0.4085 - val_loss: 0.6227 - val_R_squared: 0.3036
# Epoch 69/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4731 - R_squared: 0.3817 - val_loss: 0.5948 - val_R_squared: 0.3699
# Epoch 70/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4789 - R_squared: 0.3910 - val_loss: 0.6231 - val_R_squared: 0.3505
# Epoch 71/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4724 - R_squared: 0.4029 - val_loss: 0.6297 - val_R_squared: 0.2736
# Epoch 72/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4681 - R_squared: 0.3840 - val_loss: 0.6021 - val_R_squared: 0.3229
# Epoch 73/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4584 - R_squared: 0.3942 - val_loss: 0.5927 - val_R_squared: 0.3530
# Epoch 74/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4600 - R_squared: 0.4078 - val_loss: 0.6205 - val_R_squared: 0.3063
# Epoch 75/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4615 - R_squared: 0.4011 - val_loss: 0.6396 - val_R_squared: 0.3080
# Epoch 76/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4666 - R_squared: 0.3419 - val_loss: 0.6243 - val_R_squared: 0.2695
# Epoch 77/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4577 - R_squared: 0.4230 - val_loss: 0.6035 - val_R_squared: 0.3390
# Epoch 78/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4515 - R_squared: 0.4018 - val_loss: 0.6605 - val_R_squared: 0.1747
# Epoch 79/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4554 - R_squared: 0.4043 - val_loss: 0.6604 - val_R_squared: 0.2046
# Epoch 80/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4467 - R_squared: 0.4222 - val_loss: 0.6377 - val_R_squared: 0.2439
# Epoch 81/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4609 - R_squared: 0.4169 - val_loss: 0.6496 - val_R_squared: 0.2111
# Epoch 82/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4465 - R_squared: 0.4182 - val_loss: 0.6457 - val_R_squared: 0.2663
# Epoch 83/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4405 - R_squared: 0.4351 - val_loss: 0.6182 - val_R_squared: 0.3161
# Epoch 84/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4433 - R_squared: 0.4311 - val_loss: 0.6015 - val_R_squared: 0.3264
# Epoch 85/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4459 - R_squared: 0.4308 - val_loss: 0.6154 - val_R_squared: 0.2716
# Epoch 86/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4464 - R_squared: 0.4536 - val_loss: 0.6235 - val_R_squared: 0.2970
# Epoch 87/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4412 - R_squared: 0.4557 - val_loss: 0.6514 - val_R_squared: 0.2242
# Epoch 88/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4381 - R_squared: 0.4164 - val_loss: 0.6096 - val_R_squared: 0.3488
# Epoch 89/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4340 - R_squared: 0.4511 - val_loss: 0.6369 - val_R_squared: 0.2597
# Epoch 90/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4399 - R_squared: 0.4449 - val_loss: 0.5822 - val_R_squared: 0.3858
# Epoch 91/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4366 - R_squared: 0.4231 - val_loss: 0.6142 - val_R_squared: 0.3085
# Epoch 92/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4370 - R_squared: 0.4473 - val_loss: 0.6200 - val_R_squared: 0.2970
# Epoch 93/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4269 - R_squared: 0.4484 - val_loss: 0.5846 - val_R_squared: 0.3625
# Epoch 94/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4297 - R_squared: 0.4367 - val_loss: 0.5956 - val_R_squared: 0.3192
# Epoch 95/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4302 - R_squared: 0.4103 - val_loss: 0.5765 - val_R_squared: 0.3633
# Epoch 96/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4215 - R_squared: 0.4525 - val_loss: 0.6126 - val_R_squared: 0.2996
# Epoch 97/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4250 - R_squared: 0.4439 - val_loss: 0.6096 - val_R_squared: 0.3469
# Epoch 98/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4243 - R_squared: 0.4461 - val_loss: 0.5912 - val_R_squared: 0.3306
# Epoch 99/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4242 - R_squared: 0.4765 - val_loss: 0.6269 - val_R_squared: 0.2624
# Epoch 100/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4214 - R_squared: 0.4586 - val_loss: 0.5775 - val_R_squared: 0.3843
# Epoch 101/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4262 - R_squared: 0.4149 - val_loss: 0.5893 - val_R_squared: 0.3437
# Epoch 102/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4176 - R_squared: 0.4218 - val_loss: 0.5776 - val_R_squared: 0.3399
# Epoch 103/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4130 - R_squared: 0.4867 - val_loss: 0.5955 - val_R_squared: 0.3471
# Epoch 104/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4092 - R_squared: 0.4738 - val_loss: 0.5948 - val_R_squared: 0.3212
# Epoch 105/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4129 - R_squared: 0.4588 - val_loss: 0.5957 - val_R_squared: 0.2900
# Epoch 106/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4195 - R_squared: 0.4560 - val_loss: 0.6109 - val_R_squared: 0.2901
# Epoch 107/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4087 - R_squared: 0.4799 - val_loss: 0.5740 - val_R_squared: 0.3801
# Epoch 108/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4105 - R_squared: 0.4430 - val_loss: 0.5967 - val_R_squared: 0.3346
# Epoch 109/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4118 - R_squared: 0.4599 - val_loss: 0.5983 - val_R_squared: 0.3243
# Epoch 110/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4077 - R_squared: 0.4715 - val_loss: 0.5994 - val_R_squared: 0.2796
# Epoch 111/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4091 - R_squared: 0.4555 - val_loss: 0.5982 - val_R_squared: 0.3286
# Epoch 112/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4084 - R_squared: 0.4778 - val_loss: 0.5791 - val_R_squared: 0.3345
# Epoch 113/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3997 - R_squared: 0.4507 - val_loss: 0.5693 - val_R_squared: 0.3880
# Epoch 114/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4060 - R_squared: 0.4662 - val_loss: 0.6246 - val_R_squared: 0.2625
# Epoch 115/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4050 - R_squared: 0.4562 - val_loss: 0.6032 - val_R_squared: 0.3237
# Epoch 116/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4039 - R_squared: 0.4470 - val_loss: 0.5743 - val_R_squared: 0.3538
# Epoch 117/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3957 - R_squared: 0.4674 - val_loss: 0.5669 - val_R_squared: 0.3683
# Epoch 118/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3991 - R_squared: 0.4622 - val_loss: 0.5756 - val_R_squared: 0.3556
# Epoch 119/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3949 - R_squared: 0.4673 - val_loss: 0.5671 - val_R_squared: 0.3599
# Epoch 120/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3982 - R_squared: 0.4534 - val_loss: 0.5937 - val_R_squared: 0.3389
# Epoch 121/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3983 - R_squared: 0.5020 - val_loss: 0.5902 - val_R_squared: 0.3370
# Epoch 122/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3910 - R_squared: 0.5053 - val_loss: 0.6228 - val_R_squared: 0.2658
# Epoch 123/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3921 - R_squared: 0.4858 - val_loss: 0.5817 - val_R_squared: 0.3777
# Epoch 124/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3908 - R_squared: 0.4937 - val_loss: 0.6042 - val_R_squared: 0.3305
# Epoch 125/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4000 - R_squared: 0.4530 - val_loss: 0.5873 - val_R_squared: 0.2971
# Epoch 126/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3925 - R_squared: 0.4805 - val_loss: 0.5802 - val_R_squared: 0.3637
# Epoch 127/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3882 - R_squared: 0.4691 - val_loss: 0.5738 - val_R_squared: 0.3808
# Epoch 128/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3949 - R_squared: 0.4801 - val_loss: 0.6469 - val_R_squared: 0.2555
# Epoch 129/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3888 - R_squared: 0.5167 - val_loss: 0.5747 - val_R_squared: 0.3695
# Epoch 130/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3896 - R_squared: 0.5081 - val_loss: 0.5839 - val_R_squared: 0.3581
# Epoch 131/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3798 - R_squared: 0.5108 - val_loss: 0.5836 - val_R_squared: 0.3082
# Epoch 132/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3829 - R_squared: 0.5039 - val_loss: 0.5745 - val_R_squared: 0.3392
# Epoch 133/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3809 - R_squared: 0.4985 - val_loss: 0.6005 - val_R_squared: 0.2951
# Epoch 134/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3829 - R_squared: 0.5036 - val_loss: 0.6122 - val_R_squared: 0.2522
# Epoch 135/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3792 - R_squared: 0.5274 - val_loss: 0.6216 - val_R_squared: 0.2559
# Epoch 136/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3852 - R_squared: 0.4561 - val_loss: 0.5716 - val_R_squared: 0.3705
# Epoch 137/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3765 - R_squared: 0.4849 - val_loss: 0.5675 - val_R_squared: 0.3568
# Epoch 138/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3734 - R_squared: 0.5124 - val_loss: 0.6135 - val_R_squared: 0.3556
# Epoch 139/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3759 - R_squared: 0.5041 - val_loss: 0.5869 - val_R_squared: 0.3593
# Epoch 140/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3815 - R_squared: 0.5212 - val_loss: 0.5622 - val_R_squared: 0.3980
# Epoch 141/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3798 - R_squared: 0.5126 - val_loss: 0.6072 - val_R_squared: 0.2609
# Epoch 142/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3807 - R_squared: 0.5021 - val_loss: 0.5773 - val_R_squared: 0.3485
# Epoch 143/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3694 - R_squared: 0.5174 - val_loss: 0.5666 - val_R_squared: 0.3410
# Epoch 144/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3785 - R_squared: 0.5069 - val_loss: 0.5763 - val_R_squared: 0.3674
# Epoch 145/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3795 - R_squared: 0.5089 - val_loss: 0.5731 - val_R_squared: 0.3636
# Epoch 146/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3700 - R_squared: 0.5349 - val_loss: 0.5627 - val_R_squared: 0.4101
# Epoch 147/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3717 - R_squared: 0.5142 - val_loss: 0.6292 - val_R_squared: 0.2683
# Epoch 148/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3693 - R_squared: 0.5236 - val_loss: 0.5677 - val_R_squared: 0.3845
# Epoch 149/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3708 - R_squared: 0.4966 - val_loss: 0.5619 - val_R_squared: 0.4037
# Epoch 150/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3708 - R_squared: 0.5150 - val_loss: 0.6134 - val_R_squared: 0.3652
# Epoch 151/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3733 - R_squared: 0.4982 - val_loss: 0.6101 - val_R_squared: 0.2314
# Epoch 152/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3707 - R_squared: 0.5241 - val_loss: 0.5787 - val_R_squared: 0.3581
# Epoch 153/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3630 - R_squared: 0.5356 - val_loss: 0.5983 - val_R_squared: 0.3118
# Epoch 154/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3712 - R_squared: 0.5068 - val_loss: 0.5465 - val_R_squared: 0.3865
# Epoch 155/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3697 - R_squared: 0.4592 - val_loss: 0.5588 - val_R_squared: 0.3697
# Epoch 156/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3686 - R_squared: 0.4912 - val_loss: 0.5460 - val_R_squared: 0.3969
# Epoch 157/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3578 - R_squared: 0.5052 - val_loss: 0.6047 - val_R_squared: 0.3226
# Epoch 158/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3653 - R_squared: 0.5153 - val_loss: 0.5544 - val_R_squared: 0.4156
# Epoch 159/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3615 - R_squared: 0.5290 - val_loss: 0.5953 - val_R_squared: 0.3276
# Epoch 160/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3662 - R_squared: 0.5072 - val_loss: 0.6405 - val_R_squared: 0.1970
# Epoch 161/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3635 - R_squared: 0.5255 - val_loss: 0.5943 - val_R_squared: 0.3015
# Epoch 162/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3538 - R_squared: 0.5401 - val_loss: 0.5723 - val_R_squared: 0.3156
# Epoch 163/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3584 - R_squared: 0.5261 - val_loss: 0.5493 - val_R_squared: 0.3610
# Epoch 164/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3590 - R_squared: 0.5113 - val_loss: 0.6084 - val_R_squared: 0.2883
# Epoch 165/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3557 - R_squared: 0.5161 - val_loss: 0.5534 - val_R_squared: 0.3569
# Epoch 166/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3559 - R_squared: 0.5284 - val_loss: 0.5832 - val_R_squared: 0.3443
# Epoch 167/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3536 - R_squared: 0.5069 - val_loss: 0.5702 - val_R_squared: 0.3267
# Epoch 168/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3577 - R_squared: 0.5209 - val_loss: 0.5626 - val_R_squared: 0.3694
# Epoch 169/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3578 - R_squared: 0.5112 - val_loss: 0.5543 - val_R_squared: 0.3888
# Epoch 170/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3538 - R_squared: 0.5117 - val_loss: 0.6565 - val_R_squared: 0.1890
# Epoch 171/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3569 - R_squared: 0.5374 - val_loss: 0.5673 - val_R_squared: 0.3703
# Epoch 172/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3536 - R_squared: 0.4901 - val_loss: 0.5531 - val_R_squared: 0.3913
# Epoch 173/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3489 - R_squared: 0.5328 - val_loss: 0.5668 - val_R_squared: 0.3448
# Epoch 174/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3563 - R_squared: 0.5142 - val_loss: 0.5501 - val_R_squared: 0.3553
# Epoch 175/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3514 - R_squared: 0.5445 - val_loss: 0.5724 - val_R_squared: 0.3852
# Epoch 176/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3462 - R_squared: 0.5535 - val_loss: 0.5540 - val_R_squared: 0.3747
# Epoch 177/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3508 - R_squared: 0.5103 - val_loss: 0.5482 - val_R_squared: 0.3520
# Epoch 178/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3515 - R_squared: 0.5276 - val_loss: 0.5785 - val_R_squared: 0.3394
# Epoch 179/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3455 - R_squared: 0.5425 - val_loss: 0.5951 - val_R_squared: 0.3405
# Epoch 180/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3499 - R_squared: 0.5445 - val_loss: 0.5701 - val_R_squared: 0.3300
# Epoch 181/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3481 - R_squared: 0.5198 - val_loss: 0.5389 - val_R_squared: 0.3757
# Epoch 182/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3461 - R_squared: 0.5315 - val_loss: 0.5630 - val_R_squared: 0.3377
# Epoch 183/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3434 - R_squared: 0.5364 - val_loss: 0.5731 - val_R_squared: 0.3077
# Epoch 184/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3456 - R_squared: 0.5356 - val_loss: 0.5398 - val_R_squared: 0.3832
# Epoch 185/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3474 - R_squared: 0.5508 - val_loss: 0.5710 - val_R_squared: 0.3157
# Epoch 186/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3434 - R_squared: 0.5602 - val_loss: 0.5644 - val_R_squared: 0.4027
# Epoch 187/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3412 - R_squared: 0.5198 - val_loss: 0.6262 - val_R_squared: 0.2622
# Epoch 188/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3487 - R_squared: 0.5460 - val_loss: 0.5513 - val_R_squared: 0.3890
# Epoch 189/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3375 - R_squared: 0.5614 - val_loss: 0.5519 - val_R_squared: 0.3556
# Epoch 190/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3398 - R_squared: 0.5417 - val_loss: 0.5547 - val_R_squared: 0.3492
# Epoch 191/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3427 - R_squared: 0.5428 - val_loss: 0.5584 - val_R_squared: 0.3718
# Epoch 192/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3394 - R_squared: 0.5499 - val_loss: 0.5556 - val_R_squared: 0.3628
# Epoch 193/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3549 - R_squared: 0.5060 - val_loss: 0.5587 - val_R_squared: 0.3664
# Epoch 194/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3476 - R_squared: 0.5493 - val_loss: 0.5570 - val_R_squared: 0.3630
# Epoch 195/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3376 - R_squared: 0.5493 - val_loss: 0.5720 - val_R_squared: 0.2976
# Epoch 196/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3345 - R_squared: 0.5560 - val_loss: 0.5474 - val_R_squared: 0.3755
# Epoch 197/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3319 - R_squared: 0.5670 - val_loss: 0.5471 - val_R_squared: 0.3798
# Epoch 198/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3366 - R_squared: 0.5487 - val_loss: 0.6088 - val_R_squared: 0.2464
# Epoch 199/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3417 - R_squared: 0.5540 - val_loss: 0.5363 - val_R_squared: 0.3815
# Epoch 200/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3383 - R_squared: 0.5608 - val_loss: 0.6375 - val_R_squared: 0.2528
# Epoch 201/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3385 - R_squared: 0.5467 - val_loss: 0.5731 - val_R_squared: 0.3384
# Epoch 202/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3373 - R_squared: 0.5545 - val_loss: 0.5584 - val_R_squared: 0.3616
# Epoch 203/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3329 - R_squared: 0.5674 - val_loss: 0.5604 - val_R_squared: 0.3873
# Epoch 204/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3352 - R_squared: 0.5391 - val_loss: 0.5913 - val_R_squared: 0.3215
# Epoch 205/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3307 - R_squared: 0.5779 - val_loss: 0.5634 - val_R_squared: 0.3611
# Epoch 206/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3351 - R_squared: 0.5404 - val_loss: 0.5476 - val_R_squared: 0.3662
# Epoch 207/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3296 - R_squared: 0.5450 - val_loss: 0.5534 - val_R_squared: 0.3679
# Epoch 208/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3221 - R_squared: 0.5812 - val_loss: 0.5638 - val_R_squared: 0.3450
# Epoch 209/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3290 - R_squared: 0.5704 - val_loss: 0.5548 - val_R_squared: 0.3314
# Epoch 210/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3317 - R_squared: 0.5659 - val_loss: 0.5671 - val_R_squared: 0.3220
# Epoch 211/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3417 - R_squared: 0.5331 - val_loss: 0.5619 - val_R_squared: 0.3692
# Epoch 212/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3332 - R_squared: 0.5484 - val_loss: 0.5372 - val_R_squared: 0.3661
# Epoch 213/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3263 - R_squared: 0.5631 - val_loss: 0.5209 - val_R_squared: 0.4263
# Epoch 214/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3235 - R_squared: 0.5594 - val_loss: 0.5480 - val_R_squared: 0.3583
# Epoch 215/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3307 - R_squared: 0.5362 - val_loss: 0.5657 - val_R_squared: 0.3493
# Epoch 216/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3301 - R_squared: 0.5663 - val_loss: 0.5604 - val_R_squared: 0.3813
# Epoch 217/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3221 - R_squared: 0.5686 - val_loss: 0.5916 - val_R_squared: 0.2801
# Epoch 218/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3223 - R_squared: 0.5927 - val_loss: 0.5453 - val_R_squared: 0.4073
# Epoch 219/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3252 - R_squared: 0.5875 - val_loss: 0.5601 - val_R_squared: 0.3855
# Epoch 220/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3283 - R_squared: 0.5573 - val_loss: 0.5368 - val_R_squared: 0.4083
# Epoch 221/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3231 - R_squared: 0.5695 - val_loss: 0.5566 - val_R_squared: 0.3497
# Epoch 222/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3262 - R_squared: 0.5769 - val_loss: 0.5692 - val_R_squared: 0.3396
# Epoch 223/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3132 - R_squared: 0.5546 - val_loss: 0.5570 - val_R_squared: 0.3409
# Epoch 224/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3208 - R_squared: 0.5823 - val_loss: 0.5683 - val_R_squared: 0.3463
# Epoch 225/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3262 - R_squared: 0.5830 - val_loss: 0.5727 - val_R_squared: 0.2964
# Epoch 226/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3219 - R_squared: 0.5516 - val_loss: 0.5535 - val_R_squared: 0.3999
# Epoch 227/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3218 - R_squared: 0.5817 - val_loss: 0.5702 - val_R_squared: 0.3440
# Epoch 228/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3175 - R_squared: 0.5577 - val_loss: 0.5637 - val_R_squared: 0.3480
# Epoch 229/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3222 - R_squared: 0.5552 - val_loss: 0.5380 - val_R_squared: 0.4166
# Epoch 230/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3137 - R_squared: 0.5639 - val_loss: 0.5621 - val_R_squared: 0.3355
# Epoch 231/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3124 - R_squared: 0.5756 - val_loss: 0.5820 - val_R_squared: 0.3029
# Epoch 232/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3180 - R_squared: 0.5621 - val_loss: 0.5923 - val_R_squared: 0.2893
# Epoch 233/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3193 - R_squared: 0.5752 - val_loss: 0.5330 - val_R_squared: 0.4052
# Epoch 234/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3195 - R_squared: 0.5821 - val_loss: 0.5769 - val_R_squared: 0.3033
# Epoch 235/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3186 - R_squared: 0.5619 - val_loss: 0.5693 - val_R_squared: 0.3106
# Epoch 236/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3199 - R_squared: 0.5960 - val_loss: 0.5544 - val_R_squared: 0.3561
# Epoch 237/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3184 - R_squared: 0.5506 - val_loss: 0.5317 - val_R_squared: 0.4055
# Epoch 238/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3231 - R_squared: 0.5624 - val_loss: 0.5338 - val_R_squared: 0.3980
# Epoch 239/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3142 - R_squared: 0.5888 - val_loss: 0.5439 - val_R_squared: 0.3655
# Epoch 240/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3130 - R_squared: 0.5906 - val_loss: 0.5478 - val_R_squared: 0.3702
# Epoch 241/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3124 - R_squared: 0.5784 - val_loss: 0.5373 - val_R_squared: 0.3929
# Epoch 242/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3260 - R_squared: 0.5194 - val_loss: 0.5412 - val_R_squared: 0.3887
# Epoch 243/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3071 - R_squared: 0.5764 - val_loss: 0.5358 - val_R_squared: 0.4035
# Epoch 244/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3097 - R_squared: 0.5826 - val_loss: 0.5571 - val_R_squared: 0.3198
# Epoch 245/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3129 - R_squared: 0.5969 - val_loss: 0.5390 - val_R_squared: 0.4127
# Epoch 246/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3137 - R_squared: 0.5486 - val_loss: 0.5699 - val_R_squared: 0.2766
# Epoch 247/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3114 - R_squared: 0.5755 - val_loss: 0.5790 - val_R_squared: 0.3095
# Epoch 248/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3218 - R_squared: 0.5766 - val_loss: 0.5449 - val_R_squared: 0.4108
# Epoch 249/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3084 - R_squared: 0.5765 - val_loss: 0.5759 - val_R_squared: 0.3365
# Epoch 250/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3128 - R_squared: 0.5679 - val_loss: 0.5643 - val_R_squared: 0.3453
# Epoch 251/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3044 - R_squared: 0.5939 - val_loss: 0.5501 - val_R_squared: 0.3680
# Epoch 252/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3098 - R_squared: 0.5557 - val_loss: 0.5637 - val_R_squared: 0.3395
# Epoch 253/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3117 - R_squared: 0.5867 - val_loss: 0.5459 - val_R_squared: 0.3635
# Epoch 254/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3107 - R_squared: 0.5585 - val_loss: 0.5582 - val_R_squared: 0.3122
# Epoch 255/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3180 - R_squared: 0.5740 - val_loss: 0.5182 - val_R_squared: 0.3790
# Epoch 256/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3037 - R_squared: 0.5919 - val_loss: 0.5220 - val_R_squared: 0.4219
# Epoch 257/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3108 - R_squared: 0.5933 - val_loss: 0.5971 - val_R_squared: 0.2534
# Epoch 258/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3144 - R_squared: 0.5664 - val_loss: 0.5400 - val_R_squared: 0.3995
# Epoch 259/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3038 - R_squared: 0.5860 - val_loss: 0.5550 - val_R_squared: 0.3588
# Epoch 260/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3087 - R_squared: 0.5820 - val_loss: 0.5339 - val_R_squared: 0.3567
# Epoch 261/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3111 - R_squared: 0.5784 - val_loss: 0.5510 - val_R_squared: 0.3566
# Epoch 262/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3065 - R_squared: 0.6126 - val_loss: 0.5600 - val_R_squared: 0.3445
# Epoch 263/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3035 - R_squared: 0.5620 - val_loss: 0.5435 - val_R_squared: 0.3747
# Epoch 264/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3118 - R_squared: 0.5651 - val_loss: 0.5237 - val_R_squared: 0.4038
# Epoch 265/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3052 - R_squared: 0.5924 - val_loss: 0.5338 - val_R_squared: 0.3794
# Epoch 266/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3017 - R_squared: 0.5980 - val_loss: 0.5644 - val_R_squared: 0.3369
# Epoch 267/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3054 - R_squared: 0.5939 - val_loss: 0.5577 - val_R_squared: 0.3533
# Epoch 268/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3147 - R_squared: 0.5932 - val_loss: 0.5379 - val_R_squared: 0.3885
# Epoch 269/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3007 - R_squared: 0.5825 - val_loss: 0.5727 - val_R_squared: 0.3122
# Epoch 270/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3092 - R_squared: 0.5871 - val_loss: 0.5504 - val_R_squared: 0.3478
# Epoch 271/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3059 - R_squared: 0.6092 - val_loss: 0.5313 - val_R_squared: 0.4189
# Epoch 272/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3026 - R_squared: 0.6054 - val_loss: 0.5720 - val_R_squared: 0.3045
# Epoch 273/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3001 - R_squared: 0.5946 - val_loss: 0.5172 - val_R_squared: 0.3991
# Epoch 274/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3053 - R_squared: 0.5857 - val_loss: 0.5389 - val_R_squared: 0.3750
# Epoch 275/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3020 - R_squared: 0.6069 - val_loss: 0.5372 - val_R_squared: 0.3783
# Epoch 276/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3004 - R_squared: 0.5849 - val_loss: 0.5453 - val_R_squared: 0.3658
# Epoch 277/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3010 - R_squared: 0.5878 - val_loss: 0.5364 - val_R_squared: 0.3635
# Epoch 278/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2990 - R_squared: 0.6080 - val_loss: 0.5685 - val_R_squared: 0.3309
# Epoch 279/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2987 - R_squared: 0.5807 - val_loss: 0.5605 - val_R_squared: 0.3425
# Epoch 280/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2972 - R_squared: 0.5742 - val_loss: 0.5546 - val_R_squared: 0.3217
# Epoch 281/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3037 - R_squared: 0.5393 - val_loss: 0.5215 - val_R_squared: 0.4086
# Epoch 282/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2971 - R_squared: 0.5990 - val_loss: 0.5353 - val_R_squared: 0.3674
# Epoch 283/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2972 - R_squared: 0.5795 - val_loss: 0.5230 - val_R_squared: 0.3758
# Epoch 284/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2964 - R_squared: 0.5963 - val_loss: 0.5284 - val_R_squared: 0.4077
# Epoch 285/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2919 - R_squared: 0.5948 - val_loss: 0.5455 - val_R_squared: 0.3528
# Epoch 286/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2987 - R_squared: 0.5902 - val_loss: 0.5593 - val_R_squared: 0.3075
# Epoch 287/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3007 - R_squared: 0.5960 - val_loss: 0.5194 - val_R_squared: 0.3658
# Epoch 288/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2982 - R_squared: 0.5658 - val_loss: 0.5358 - val_R_squared: 0.4017
# Epoch 289/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2983 - R_squared: 0.6036 - val_loss: 0.5158 - val_R_squared: 0.3964
# Epoch 290/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2886 - R_squared: 0.6156 - val_loss: 0.5311 - val_R_squared: 0.3586
# Epoch 291/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3004 - R_squared: 0.5840 - val_loss: 0.5308 - val_R_squared: 0.3786
# Epoch 292/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2988 - R_squared: 0.5871 - val_loss: 0.5372 - val_R_squared: 0.3786
# Epoch 293/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2954 - R_squared: 0.5786 - val_loss: 0.5248 - val_R_squared: 0.3911
# Epoch 294/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2882 - R_squared: 0.6071 - val_loss: 0.5403 - val_R_squared: 0.3428
# Epoch 295/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2966 - R_squared: 0.6132 - val_loss: 0.5590 - val_R_squared: 0.3197
# Epoch 296/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2901 - R_squared: 0.6365 - val_loss: 0.5325 - val_R_squared: 0.3960
# Epoch 297/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2963 - R_squared: 0.6041 - val_loss: 0.5536 - val_R_squared: 0.3199
# Epoch 298/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2861 - R_squared: 0.6233 - val_loss: 0.5545 - val_R_squared: 0.3392
# Epoch 299/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2926 - R_squared: 0.6244 - val_loss: 0.5820 - val_R_squared: 0.3113
# Epoch 300/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2998 - R_squared: 0.6021 - val_loss: 0.5576 - val_R_squared: 0.3464
# Epoch 301/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2898 - R_squared: 0.6152 - val_loss: 0.5394 - val_R_squared: 0.3734
# Epoch 302/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2836 - R_squared: 0.6274 - val_loss: 0.5307 - val_R_squared: 0.3585
# Epoch 303/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2951 - R_squared: 0.6015 - val_loss: 0.5346 - val_R_squared: 0.3958
# Epoch 304/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2895 - R_squared: 0.5795 - val_loss: 0.5281 - val_R_squared: 0.4067
# Epoch 305/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2853 - R_squared: 0.6143 - val_loss: 0.5081 - val_R_squared: 0.4352
# Epoch 306/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2889 - R_squared: 0.6148 - val_loss: 0.5468 - val_R_squared: 0.3891
# Epoch 307/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3012 - R_squared: 0.6142 - val_loss: 0.5351 - val_R_squared: 0.3875
# Epoch 308/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2928 - R_squared: 0.5784 - val_loss: 0.5311 - val_R_squared: 0.4182
# Epoch 309/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2874 - R_squared: 0.6065 - val_loss: 0.5330 - val_R_squared: 0.3691
# Epoch 310/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2819 - R_squared: 0.6054 - val_loss: 0.5577 - val_R_squared: 0.3817
# Epoch 311/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2920 - R_squared: 0.6097 - val_loss: 0.5249 - val_R_squared: 0.4142
# Epoch 312/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2881 - R_squared: 0.6037 - val_loss: 0.5312 - val_R_squared: 0.3862
# Epoch 313/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2816 - R_squared: 0.6090 - val_loss: 0.5501 - val_R_squared: 0.3582
# Epoch 314/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2847 - R_squared: 0.6064 - val_loss: 0.5733 - val_R_squared: 0.3093
# Epoch 315/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2876 - R_squared: 0.6199 - val_loss: 0.5191 - val_R_squared: 0.4058
# Epoch 316/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2845 - R_squared: 0.5940 - val_loss: 0.5458 - val_R_squared: 0.3823
# Epoch 317/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2933 - R_squared: 0.6242 - val_loss: 0.5162 - val_R_squared: 0.4059
# Epoch 318/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2868 - R_squared: 0.6073 - val_loss: 0.5465 - val_R_squared: 0.3748
# Epoch 319/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2801 - R_squared: 0.5781 - val_loss: 0.5614 - val_R_squared: 0.3466
# Epoch 320/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2892 - R_squared: 0.6129 - val_loss: 0.5268 - val_R_squared: 0.4107
# Epoch 321/500
# ...
# Epoch 393/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2587 - R_squared: 0.6566 - val_loss: 0.5164 - val_R_squared: 0.3964
# Epoch 394/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2686 - R_squared: 0.6368 - val_loss: 0.5317 - val_R_squared: 0.3963
# Epoch 395/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2673 - R_squared: 0.6327 - val_loss: 0.5174 - val_R_squared: 0.3945
# Epoch 396/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2609 - R_squared: 0.6352 - val_loss: 0.5062 - val_R_squared: 0.4023
# Epoch 397/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2585 - R_squared: 0.6421 - val_loss: 0.5398 - val_R_squared: 0.3587
# Epoch 398/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2640 - R_squared: 0.6312 - val_loss: 0.5130 - val_R_squared: 0.3993
# Epoch 399/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2581 - R_squared: 0.6422 - val_loss: 0.5237 - val_R_squared: 0.4121
# Epoch 400/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2622 - R_squared: 0.6425 - val_loss: 0.5259 - val_R_squared: 0.3497
# Epoch 401/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2629 - R_squared: 0.6167 - val_loss: 0.5314 - val_R_squared: 0.3915
# Epoch 402/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2580 - R_squared: 0.6268 - val_loss: 0.5024 - val_R_squared: 0.4306
# Epoch 403/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2562 - R_squared: 0.6552 - val_loss: 0.5277 - val_R_squared: 0.3446
# Epoch 404/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2516 - R_squared: 0.6568 - val_loss: 0.5193 - val_R_squared: 0.3858
# Epoch 405/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2581 - R_squared: 0.6308 - val_loss: 0.5245 - val_R_squared: 0.3745
# Epoch 406/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2649 - R_squared: 0.6366 - val_loss: 0.5229 - val_R_squared: 0.3918
# Epoch 407/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2533 - R_squared: 0.6015 - val_loss: 0.5202 - val_R_squared: 0.4021
# Epoch 408/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2608 - R_squared: 0.6427 - val_loss: 0.5123 - val_R_squared: 0.4113
# Epoch 409/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2547 - R_squared: 0.6259 - val_loss: 0.5008 - val_R_squared: 0.4288
# Epoch 410/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2613 - R_squared: 0.6555 - val_loss: 0.5081 - val_R_squared: 0.4094
# Epoch 411/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2564 - R_squared: 0.6252 - val_loss: 0.5231 - val_R_squared: 0.3722
# Epoch 412/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2602 - R_squared: 0.6504 - val_loss: 0.5298 - val_R_squared: 0.3886
# Epoch 413/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2565 - R_squared: 0.6186 - val_loss: 0.5197 - val_R_squared: 0.3829
# Epoch 414/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2580 - R_squared: 0.6344 - val_loss: 0.5122 - val_R_squared: 0.4022
# Epoch 415/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2611 - R_squared: 0.6061 - val_loss: 0.5186 - val_R_squared: 0.3966
# Epoch 416/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2589 - R_squared: 0.6225 - val_loss: 0.5227 - val_R_squared: 0.3802
# Epoch 417/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2589 - R_squared: 0.6300 - val_loss: 0.5250 - val_R_squared: 0.4087
# Epoch 418/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2587 - R_squared: 0.6453 - val_loss: 0.5509 - val_R_squared: 0.3390
# Epoch 419/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2551 - R_squared: 0.6463 - val_loss: 0.5124 - val_R_squared: 0.4127
# Epoch 420/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2531 - R_squared: 0.6631 - val_loss: 0.5331 - val_R_squared: 0.3765
# Epoch 421/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2625 - R_squared: 0.6337 - val_loss: 0.5345 - val_R_squared: 0.3789
# Epoch 422/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2550 - R_squared: 0.6285 - val_loss: 0.5364 - val_R_squared: 0.3502
# Epoch 423/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2530 - R_squared: 0.6486 - val_loss: 0.5119 - val_R_squared: 0.3902
# Epoch 424/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2544 - R_squared: 0.6355 - val_loss: 0.5248 - val_R_squared: 0.3923
# Epoch 425/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2566 - R_squared: 0.6591 - val_loss: 0.5279 - val_R_squared: 0.3665
# Epoch 426/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2604 - R_squared: 0.6300 - val_loss: 0.5152 - val_R_squared: 0.4389
# Epoch 427/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2540 - R_squared: 0.6629 - val_loss: 0.5204 - val_R_squared: 0.3866
# Epoch 428/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2566 - R_squared: 0.6163 - val_loss: 0.5112 - val_R_squared: 0.3992
# Epoch 429/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2519 - R_squared: 0.6480 - val_loss: 0.5610 - val_R_squared: 0.3244
# Epoch 430/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2518 - R_squared: 0.6550 - val_loss: 0.5358 - val_R_squared: 0.3367
# Epoch 431/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2544 - R_squared: 0.6516 - val_loss: 0.5222 - val_R_squared: 0.3941
# Epoch 432/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2549 - R_squared: 0.6625 - val_loss: 0.5223 - val_R_squared: 0.3495
# Epoch 433/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2532 - R_squared: 0.6522 - val_loss: 0.5194 - val_R_squared: 0.3988
# Epoch 434/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2479 - R_squared: 0.6503 - val_loss: 0.5506 - val_R_squared: 0.3235
# Epoch 435/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2496 - R_squared: 0.6383 - val_loss: 0.5439 - val_R_squared: 0.3500
# Epoch 436/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2558 - R_squared: 0.6035 - val_loss: 0.5356 - val_R_squared: 0.3415
# Epoch 437/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2489 - R_squared: 0.6422 - val_loss: 0.5432 - val_R_squared: 0.3551
# Epoch 438/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2540 - R_squared: 0.6539 - val_loss: 0.5272 - val_R_squared: 0.3846
# Epoch 439/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2467 - R_squared: 0.6233 - val_loss: 0.5095 - val_R_squared: 0.4293
# Epoch 440/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2570 - R_squared: 0.6526 - val_loss: 0.5063 - val_R_squared: 0.4023
# Epoch 441/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2563 - R_squared: 0.6490 - val_loss: 0.5309 - val_R_squared: 0.3635
# Epoch 442/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2504 - R_squared: 0.6587 - val_loss: 0.5359 - val_R_squared: 0.3370
# Epoch 443/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2493 - R_squared: 0.6561 - val_loss: 0.4964 - val_R_squared: 0.4103
# Epoch 444/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2524 - R_squared: 0.6614 - val_loss: 0.5044 - val_R_squared: 0.4268
# Epoch 445/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2484 - R_squared: 0.6602 - val_loss: 0.5388 - val_R_squared: 0.3975
# Epoch 446/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2572 - R_squared: 0.6270 - val_loss: 0.5324 - val_R_squared: 0.3980
# Epoch 447/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2415 - R_squared: 0.6369 - val_loss: 0.5236 - val_R_squared: 0.3720
# Epoch 448/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2531 - R_squared: 0.6358 - val_loss: 0.5122 - val_R_squared: 0.4070
# Epoch 449/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2473 - R_squared: 0.6483 - val_loss: 0.5325 - val_R_squared: 0.3287
# Epoch 450/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2481 - R_squared: 0.6644 - val_loss: 0.5280 - val_R_squared: 0.3818
# Epoch 451/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2595 - R_squared: 0.6105 - val_loss: 0.5245 - val_R_squared: 0.3727
# Epoch 452/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2484 - R_squared: 0.6395 - val_loss: 0.5110 - val_R_squared: 0.4022
# Epoch 453/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2510 - R_squared: 0.6576 - val_loss: 0.5166 - val_R_squared: 0.3846
# Epoch 454/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2464 - R_squared: 0.6187 - val_loss: 0.5297 - val_R_squared: 0.4056
# Epoch 455/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2514 - R_squared: 0.6533 - val_loss: 0.5137 - val_R_squared: 0.3815
# Epoch 456/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2511 - R_squared: 0.6491 - val_loss: 0.5588 - val_R_squared: 0.3157
# Epoch 457/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2485 - R_squared: 0.6318 - val_loss: 0.5023 - val_R_squared: 0.4257
# Epoch 458/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2434 - R_squared: 0.6683 - val_loss: 0.5146 - val_R_squared: 0.4194
# Epoch 459/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2478 - R_squared: 0.6341 - val_loss: 0.5276 - val_R_squared: 0.3622
# Epoch 460/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2494 - R_squared: 0.6476 - val_loss: 0.5369 - val_R_squared: 0.3341
# Epoch 461/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2497 - R_squared: 0.6490 - val_loss: 0.4950 - val_R_squared: 0.4107
# Epoch 462/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2410 - R_squared: 0.6316 - val_loss: 0.4999 - val_R_squared: 0.4195
# Epoch 463/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2490 - R_squared: 0.6633 - val_loss: 0.5288 - val_R_squared: 0.3289
# Epoch 464/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2403 - R_squared: 0.6616 - val_loss: 0.5006 - val_R_squared: 0.4248
# Epoch 465/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2486 - R_squared: 0.6486 - val_loss: 0.5363 - val_R_squared: 0.3639
# Epoch 466/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2436 - R_squared: 0.6631 - val_loss: 0.5295 - val_R_squared: 0.3622
# Epoch 467/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2423 - R_squared: 0.6626 - val_loss: 0.5298 - val_R_squared: 0.3544
# Epoch 468/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2487 - R_squared: 0.6512 - val_loss: 0.5388 - val_R_squared: 0.3541
# Epoch 469/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2456 - R_squared: 0.6352 - val_loss: 0.5128 - val_R_squared: 0.3803
# Epoch 470/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2447 - R_squared: 0.6506 - val_loss: 0.5411 - val_R_squared: 0.3883
# Epoch 471/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2473 - R_squared: 0.6430 - val_loss: 0.5266 - val_R_squared: 0.3583
# Epoch 472/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2464 - R_squared: 0.6356 - val_loss: 0.5167 - val_R_squared: 0.3860
# Epoch 473/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2433 - R_squared: 0.6627 - val_loss: 0.5248 - val_R_squared: 0.3754
# Epoch 474/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2399 - R_squared: 0.6614 - val_loss: 0.5202 - val_R_squared: 0.4013
# Epoch 475/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2430 - R_squared: 0.6512 - val_loss: 0.5377 - val_R_squared: 0.3696
# Epoch 476/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2474 - R_squared: 0.6188 - val_loss: 0.5113 - val_R_squared: 0.4086
# Epoch 477/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2521 - R_squared: 0.6354 - val_loss: 0.5305 - val_R_squared: 0.3509
# Epoch 478/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2379 - R_squared: 0.6579 - val_loss: 0.4960 - val_R_squared: 0.4274
# Epoch 479/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2451 - R_squared: 0.6773 - val_loss: 0.5252 - val_R_squared: 0.3626
# Epoch 480/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2417 - R_squared: 0.6733 - val_loss: 0.5016 - val_R_squared: 0.3890
# Epoch 481/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2424 - R_squared: 0.6741 - val_loss: 0.5481 - val_R_squared: 0.3170
# Epoch 482/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2464 - R_squared: 0.6781 - val_loss: 0.5485 - val_R_squared: 0.3228
# Epoch 483/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2448 - R_squared: 0.6413 - val_loss: 0.5204 - val_R_squared: 0.3823
# Epoch 484/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2483 - R_squared: 0.6264 - val_loss: 0.4968 - val_R_squared: 0.4239
# Epoch 485/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2456 - R_squared: 0.6571 - val_loss: 0.4890 - val_R_squared: 0.4306
# Epoch 486/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2447 - R_squared: 0.6718 - val_loss: 0.5060 - val_R_squared: 0.4105
# Epoch 487/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2425 - R_squared: 0.6595 - val_loss: 0.5348 - val_R_squared: 0.3791
# Epoch 488/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2432 - R_squared: 0.6447 - val_loss: 0.5339 - val_R_squared: 0.3478
# Epoch 489/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2458 - R_squared: 0.6389 - val_loss: 0.5493 - val_R_squared: 0.3274
# Epoch 490/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2394 - R_squared: 0.6619 - val_loss: 0.4923 - val_R_squared: 0.4186
# Epoch 491/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2327 - R_squared: 0.6762 - val_loss: 0.5331 - val_R_squared: 0.3876
# Epoch 492/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2415 - R_squared: 0.6594 - val_loss: 0.5064 - val_R_squared: 0.4186
# Epoch 493/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2423 - R_squared: 0.6381 - val_loss: 0.4940 - val_R_squared: 0.4152
# Epoch 494/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2429 - R_squared: 0.6622 - val_loss: 0.5324 - val_R_squared: 0.3320
# Epoch 495/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2385 - R_squared: 0.6670 - val_loss: 0.4967 - val_R_squared: 0.4139
# Epoch 496/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2391 - R_squared: 0.6815 - val_loss: 0.5186 - val_R_squared: 0.4119
# Epoch 497/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2331 - R_squared: 0.6612 - val_loss: 0.4922 - val_R_squared: 0.4145
# Epoch 498/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2339 - R_squared: 0.6798 - val_loss: 0.5348 - val_R_squared: 0.3467
# Epoch 499/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2400 - R_squared: 0.6533 - val_loss: 0.5077 - val_R_squared: 0.3893
# Epoch 500/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2326 - R_squared: 0.6739 - val_loss: 0.5085 - val_R_squared: 0.3943

# %%
hist = NN_model.history

# %%
hist.history.keys()
# Out:
# dict_keys(['loss', 'R_squared', 'val_loss', 'val_R_squared'])

# %%
plt.plot(range(len(hist.history['R_squared'])), hist.history['R_squared'], label = 'training')
plt.plot(range(len(hist.history['val_R_squared'])), hist.history['val_R_squared'], label = 'validation')
plt.legend(loc='best')
plt.xlabel('Epochs')
plt.ylabel('R2 score')
# Out:
# Text(0, 0.5, 'R2 score')

# %% [markdown]
# **The neural networks although improves the training R2 score over epochs, fails to improve the R2 score on test data.**

# %% [markdown]
# # **CONCLUSION**

# %% [markdown]
# 1. **The temperature/ humidity features showed little to no pearson correlation w.r.t target variable (<1%), although being highly correlated within themselves.**
#
# 2. **The time zone of the day plays an important role in deciding power consumption of appliances.**
#
# 3. **The best Algorithm to use for this dataset is Extra Trees Regressor (tree based algorithm)**
#
# 4. **PCA helped us to reduce our feature set dimension considerably without affecting performance of our models significantly.**
#
# 5. **The untuned model was able to explain 64.5% of variance (R2 score = 0.645) on test set, while the tuned model was able to explain 64.9% of variance (R2 score = 0.649) on test set which is a tiny improvement of < 1 %**
#
# 6. **The least RMSE score on test data set is found to be around 0.6 by Extra trees regressor model, which is considerably good compared to other models.**
#
# 7. **Tree based models are by far the best model while dealing with data set that has most of its features having no linear correlation with target variable. For similar reasons, linear models such as linear regression, Ridge and Lasso perform the worst.**
